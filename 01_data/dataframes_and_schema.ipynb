# %% [markdown]
# <a href="https://colab.research.google.com/github/uvasds-systems/ds3022/blob/main/01_data/dataframes_and_schema.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import polars as pl

url = "https://s3.amazonaws.com/uvasds-systems/data/FLIGHT_LOGS.csv"

# %% [markdown]
# # Pandas

# %%
# pandas
df_pd = pd.read_csv(url)
# print(df_pd.head())

len(df_pd)
df_pd.shape
# Out:
# (1000, 20)

# %%
df_pd.dtypes
df_pd.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   flight_number      1000 non-null   str
#  1   airline_name       1000 non-null   str
#  2   departure_airport  1000 non-null   str
#  3   departure_city     1000 non-null   str
#  4   departure_country  1000 non-null   str
#  5   departure_time     1000 non-null   str
#  6   arrival_airport    1000 non-null   str
#  7   arrival_city       1000 non-null   str
#  8   arrival_country    1000 non-null   str
#  9   duration_hours     1000 non-null   int64
#  10  passenger_name     1000 non-null   str
#  11  passenger_age      1000 non-null   int64
#  12  passenger_gender   1000 non-null   str
#  13  seat_number        1000 non-null   str
#  14  ticket_price       1000 non-null   str
#  15  baggage_weight     1000 non-null   int64
#  16  meal_preference    1000 non-null   str
#  17  flight_status      1000 non-null   str
#  18  gate_number        1000 non-null   int64
#  19  arrival_date       1000 non-null   str
# dtypes: int64(4), str(16)
# memory usage: 156.4 KB

# %% [markdown]
# # Polars

# %%
# polars
df_pl = pl.read_csv(url)
print(df_pl.head())

df_pl.height
df_pl.shape
# Out:
# shape: (5, 20)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ flight_nu ┆ airline_n ┆ departure ┆ departure ┆ … ┆ meal_pref ┆ flight_st ┆ gate_numb ┆ arrival_ │
# │ mber      ┆ ame       ┆ _airport  ┆ _city     ┆   ┆ erence    ┆ atus      ┆ er        ┆ date     │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ str       ┆ str       ┆ str       ┆   ┆ str       ┆ str       ┆ i64       ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ AI2923    ┆ Air India ┆ Indira    ┆ Delhi     ┆ … ┆ Vegan     ┆ On time   ┆ 34        ┆ 5/4/2022 │
# │           ┆           ┆ Gandhi    ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Internati ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ onal      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ LH7040    ┆ Lufthansa ┆ Frankfurt ┆ Frankfurt ┆ … ┆ Vegan     ┆ Cancelled ┆ 49        ┆ 1/29/202 │
# │           ┆           ┆ Airport   ┆           ┆   ┆           ┆           ┆           ┆ 2        │
# │ AA4621    ┆ American  ┆ John F.   ┆ New York  ┆ … ┆ Vegetaria ┆ On time   ┆ 24        ┆ 3/1/2022 │
# │           ┆ Airlines  ┆ Kennedy   ┆           ┆   ┆ n         ┆           ┆           ┆          │
# │           ┆           ┆ Internati ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ onal      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ SK8375    ┆ SAS Scand ┆ Copenhage ┆ Copenhage ┆ … ┆ Vegetaria ┆ Delayed   ┆ 27        ┆ 10/29/20 │
# │           ┆ inavian   ┆ n Airport ┆ n         ┆   ┆ n         ┆           ┆           ┆ 22       │
# │ LH3446    ┆ Lufthansa ┆ Frankfurt ┆ Frankfurt ┆ … ┆ Vegan     ┆ On time   ┆ 1         ┆ 11/9/202 │
# │           ┆           ┆ Airport   ┆           ┆   ┆           ┆           ┆           ┆ 2        │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
# (1000, 20)

# %%
df_pl.schema

print("\nSchema:")
for name, dtype in df_pl.schema.items():
    print(f"  {name}: {dtype}")
# Out:
# Schema:
#   flight_number: String
#   airline_name: String
#   departure_airport: String
#   departure_city: String
#   departure_country: String
#   departure_time: String
#   arrival_airport: String
#   arrival_city: String
#   arrival_country: String
#   duration_hours: Int64
#   passenger_name: String
#   passenger_age: Int64
#   passenger_gender: String
#   seat_number: String
#   ticket_price: String
#   baggage_weight: Int64
#   meal_preference: String
#   flight_status: String
#   gate_number: Int64
#   arrival_date: String
